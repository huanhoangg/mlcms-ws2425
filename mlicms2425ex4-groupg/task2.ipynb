# %%
import matplotlib.pyplot as plt
import numpy as np
from utils import find_saddle_node_equilibria, evaluate_shifted_stability, find_shifted_saddle_node_equilibria, \
    evaluate_basic_stability

# %%
from utils import plot_bifurcation_diagram

# Generate data for both systems
alphas1 = np.linspace(-0.5, 1, 500)  # First system
alphas2 = np.linspace(2, 4, 500)     # Second system

# First system
fig1, ax1 = plot_bifurcation_diagram(
    alphas=np.linspace(0, 0.5, 500),
    find_equilibria=find_saddle_node_equilibria,
    evaluate_stability=evaluate_basic_stability,
    title=r'Bifurcation diagram for $\dot{x} = \alpha - x^2$',
    xlim=(0, 0.5),
    ylim=(-1, 1),
    save_loc='bifurcation1.png',
    task_type="analytical"
)

# Second system
fig2, ax2 = plot_bifurcation_diagram(
    alphas=np.linspace(3.0, 4.0, 500),
    find_equilibria=find_shifted_saddle_node_equilibria,
    evaluate_stability=evaluate_shifted_stability,
    title=r'Bifurcation diagram for $\dot{x} = \alpha - 2x^2 - 3$',
    xlim=(3.0, 4.0),
    ylim=(-2, 1),
    save_loc='bifurcation2.png',
    task_type="analytical"
)
